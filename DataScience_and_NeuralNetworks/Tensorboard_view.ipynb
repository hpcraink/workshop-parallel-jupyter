# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %% [markdown]
# When you execute the next cell, the Tensorboard will appear. The results from PyTorch and Tensorflow will appear in different graphs, and for the most part Tensorflow will have more different graphs. Because Tensorboard was developed by the creators of Tensorflow, the logging integration with Tensorflow is much simpler with rich default settings.
#
# Your task here is to explore what is displayed in Tensorboard.

# %%
# %tensorboard --logdir ./output/logs
